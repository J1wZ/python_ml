# %% [markdown]
# Загрузите набор данных из файла car_data.csv к текущему домашнему заданию.

# %%
import pandas as pd

df = pd.read_csv('car_data.csv', index_col=0)
df
# Out:
#             Car_id       Date Customer Name  Gender  Annual Income  \
# 0     C_CND_000001   1/2/2022     Geraldine    Male          13500
# 1     C_CND_000002   1/2/2022           Gia    Male        1480000
# 2     C_CND_000003   1/2/2022        Gianna    Male        1035000
# 3     C_CND_000004   1/2/2022       Giselle    Male          13500
# 4     C_CND_000005   1/2/2022         Grace    Male        1465000
# ...            ...        ...           ...     ...            ...
# 4996  C_CND_004997  8/28/2022         Elena  Female        3900000
# 4997  C_CND_004998  8/28/2022         Elina    Male        1500000
# 4998  C_CND_004999  8/28/2022     Elizabeth    Male        1850000
# 4999  C_CND_005000  8/28/2022          Ella    Male          13500
# 5000  C_CND_005001  8/28/2022         Emily    Male        1700000
#
#                               Dealer_Name     Company       Model  \
# 0     Buddy Storbeck's Diesel Service Inc        Ford  Expedition
# ...

# %% [markdown]
# Сформировать и отобразить данные в виде трех разных графиков:
# С использованием диаграммы boxplot визуализируйте зависимость числового признака от категориального. Ящики в диаграмме визуализировать горизонтально.Используйте библиотеку seaborn или plotly.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))  
sns.boxplot(x="Price ($)", y="Body Style", data=df) 
plt.title('Ящиковая диаграмма цены машины по видам автомобиля')
plt.xlabel('Цена автомобиля')
plt.ylabel('Вид')
plt.show()

# %% [markdown]
# Постройте Scatterplot для двух числовых признаков из набора данных,отметив разными цветами категориальный признак.Использовать любую из библиотек:matplotlib,seaborn,plotly.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  
sns.scatterplot(x='Price ($)', y='Annual Income', data=df, hue='Color')
plt.title('Диаграмма рассеяния по цене и годовой прибыли в зависимотси от цвета авто')
plt.xlabel('Цена')
plt.ylabel('Годовая прибыль')
plt.show()

# %% [markdown]
# Постройте диаграмму Countplot для нескольких категориальных признаков(минимально взять 2 признака) из набора данных.Используйте библиотеку seaborn или plotly.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4)) 
sns.countplot(x ='Color', hue = "Engine", data = df)
plt.title('Барная диаграма распределения цвета авто')
plt.xlabel('Цвет')
plt.ylabel('Кол-во авто')
plt.show()
